# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = 'C:\\Windows\\Fonts\\malgun.ttf').get_name()
plt.rc('font', family = font_name)
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ##  XML

# %%
"""
*.XML(Extensible Markup Language)

	1)메타언어
		GML -> SGML -> XML
	2)데이터를 위한 언어
	3)DB
	4)데이터의 표준화 : 이기종 시스템간의 정보교환, 웹서비스, 
		유비쿼터스, 사물인터넷 기타 등등...
	
*. XML 문법

	XML(.xml), DTD(.dtd), XML스키마(.xsd), XSL(XML Style Sheet Language, XSLT)
11
	(1) XML 문서 종류
        1) Well-Formed XML Document(잘 짜여진 문서)
		2) Valid XML Document(유효한 문서)
			
	(2) XML 기본 구조
		Prolog	- 1개
		Element	- 1개
		Misc	- 0개 이상

	(3) Element 문법
		- 작성 규칙
			a) 모든 XML문서는 반드시 단 하나의 루트 엘리먼트를 가진다.
			b) 루트 엘리먼트는 여러 개의 자식 엘리먼트를 가질 수 있고 또 그 자식도 자신의 자식을 가질 수 있다.
			c) 시작태그와 끝태그는 반드시 짝을 이루어야 한다.
			d) "<"는 값으로 사용 불가. ">"는 사용할 수 있으나가급적 사용 금지
			e) "<"와 ">" 다음에 공백문자가 올 수 없으며 반드시 시작태그와 끝태그의 이름이 같아야 한다.
					
		- 종류
			a) 내용을 가지는 엘리먼트
			b) 내용이 없는 엘리먼트

		- 내용에 대한 종류
			a) 문자 데이터
			b) 자식 엘리먼트
			c) 엔티티 또는 문자 참조(&엔티티명;)
			d) CDATA Section
			e) 프로세싱 지시자
			f) 주석
			g) 공백 문자열

	(4) DTD 
		- 종류
			내부 DTD
			외부 DTD

		- 구성 요소
			엘리먼트 선언
			속성(attribute) 선언
			Entity 선언
			Notation 선언
			프로세싱 지시자
			파라미터 엔티티 참조
			주석
			공백
			conditional section
				
		- 문서 유형 선언
			<!DOCTYPE 루트엘리먼트명 SYSTEM 또는 PUBLIC "식별자">
			DOCTYPE은 반드시 대문자
			SYSTEM은 특정 단체나 업체내부에서 사용되는 경우
			PUBLIC은 공개
			식별자는 다운로드 받을 수 있는 경로
			PUBLIC일 경우 추가된 식별자
			+-//DTD를 개발 및 유지보수 업체명//DTD명 및 버전번호//사용된 언어

		- 엘리먼트 선언
			<!ELEMENT 엘리먼트명 컨텐트 유형>
			컨텐트 유형
				#PCDATA	: 내용으로 문자데이터만 갖는 엘리먼트
				자식 엘리먼트
					, : 작성 순서
						| : 선택
						? : 생략하거나 한번만 작성
						+ : 한번 이상
						* : 생략하거나 여러번 작성
						기호 없음 : 단 한번만 작성
					EMPTY
					MIXED : 문자데이터 또는 자식엘리먼트를 혼합형태
					ANY

			- ATTRIBUTE 선언
				<!ATTLIST 엘리먼트명 속성명 속성유형 디폴트선언>
				속성 유형
					CDATA	: 문자 데이터
					ENUMERATION	: dtd에 나열된 값 중 하나가 와야 함
					ID : 유일한 값을 지정
					IDREF/IDREFS : ID값을 참조
					NMTOKEN/NMTOKENS : 이름 작성 규칙을 준수하는 
						데이터만 사용
					NOTATION : dtd에 명시적으로 선언된 notation만 사용가능
					ENTITY : dtd에 명시적으로 선언된 entity만 사용 가능
		
		(5) 네임 스페이스
			CML
			-----
			<?xml version=1.0>
			<정보>
				<고유번호>111111-1111111</고유번호>
				<이름>홍길동</이름>
				...
			</정보>
			
			PML
			-----
			<?xml version=1.0>
			<정보>
				<고유번호>LC100</고유번호>
				<이름>캠코더</이름>
				...
			</정보>
			
			OML
			-----
			<?xml version=1.0>
			<주문정보 xmlns:고객="http://www.a.com/2017/Custom"
				xmlns:상품="http://www.a.com/2017/Product"
				xmlns="http://www.a.com/2017/Order">
				<주문번호>1</주문번호>
				<주문수량>10</주문수량>
				<결제>
					<방법>현금</방법>
					<금액>10000000</금액>
				</결제>
				
				<고객:고유번호>111111-1111111</고객:고유번호>
				<고객:이름>홍길동</고객:이름>
				
				<상품:고유번호>LC100</상품:고유번호>
				<상품:이름>캠코더</상품:이름>
				...
			</주문정보>
"""
# Out:
# '\n*.XML(Extensible Markup Language)\n\n\t1)메타언어\n\t\tGML -> SGML -> XML\n\t2)데이터를 위한 언어\n\t3)DB\n\t4)데이터의 표준화 : 이기종 시스템간의 정보교환, 웹서비스, \n\t\t유비쿼터스, 사물인터넷 기타 등등...\n\t\n*. XML 문법\n\n\tXML(.xml), DTD(.dtd), XML스키마(.xsd), XSL(XML Style Sheet Language, XSLT)\n11\n\t(1) XML 문서 종류\n        1) Well-Formed XML Document(잘 짜여진 문서)\n\t\t2) Valid XML Document(유효한 문서)\n\t\t\t\n\t(2) XML 기본 구조\n\t\tProlog\t- 1개\n\t\tElement\t- 1개\n\t\tMisc\t- 0개 이상\n\n\t(3) Element 문법\n\t\t- 작성 규칙\n\t\t\ta) 모든 XML문서는 반드시 단 하나의 루트 엘리먼트를 가진다.\n\t\t\tb) 루트 엘리먼트는 여러 개의 자식 엘리먼트를 가질 수 있고 또 그 자식도 자신의 자식을 가질 수 있다.\n\t\t\tc) 시작태그와 끝태그는 반드시 짝을 이루어야 한다.\n\t\t\td) "<"는 값으로 사용 불가. ">"는 사용할 수 있으나가급적 사용 금지\n\t\t\te) "<"와 ">" 다음에 공백문자가 올 수 없으며 반드시 시작태그와 끝태그의 이름이 같아야 한다.\n\t\t\t\t\t\n\t\t- 종류\n\t\t\ta) 내용을 가지는 엘리먼트\n\t\t\tb) 내용이 없는 엘리먼트\n\n\t\t- 내용에 대한 종류\n\t\t\ta) 문자 데이터\n\t\t\tb) 자식 엘리먼트\n\t\t\tc) 엔티티 또는 문자 참조(&엔티티명;)\n\t\t\td) CDATA Section\n\t\t\te) 프로세싱 지시자\n\t\t\tf) 주석\n\t\t\tg) 공백 문자열\n\n\t(4) DTD \n\t\t- 종류\n\t\t\t내부 DTD\n\t\t\t외부 DTD\n\n\t\t- 구성 요소\n\t\t\t엘리먼트 선언\n\t\t\t속성(attribute) 선언\n\t\t\tEntity 선언\n\t\t\tNotation 선언\n\t\t\t프로세싱 지시자\n\t\t\t파라미터 엔티티 참조\n\t\t\t주석\n\t\t\t공백\n\t\t\tconditional section\n\t\t\t\t\n\t\t- 문서 유형 선언\n\t\t\t<!DOCTYPE 루트엘리먼트명 SYSTEM 또는 PUBLIC "식별자">\n\t\t\tDOCTYPE은 반드시 대문자\n\t\t\tSYSTEM은 특정 단체나 업체내부에서 사용되는 경우\n\t\t\tPUBLIC은 공개\n\t\t\t식별자는 다운로드 받을 수 있는 경로\n\t\t\tPUBLIC일 경우 추가된 식별자\n\t\t\t+-//DTD를 개발 및 유지보수 업체명//DTD명 및 버전번호//사용된 언어\n\n\t\t- 엘리먼트 선언\n\t\t\t<!ELEMENT 엘리먼트명 컨텐트 유형>\n\t\t\t컨텐트 유형\n\t\t\t\t#PCDATA\t: 내용으로 문자데이터만 갖는 엘리먼트\n\t\t\t\t자식 엘리먼트\n\t\t\t\t\t, : 작성 순서\n\t\t\t\t\t\t| : 선택\n\t\t\t\t\t\t? : 생략하거나 한번만 작성\n\t\t\t\t\t\t+ : 한번 이상\n\t\t\t\t\t\t* : 생략하거나 여러번 작성\n\t\t\t\t\t\t기호 없음 : 단 한번만 작성\n\t\t\t\t\tEMPTY\n\t\t\t\t\tMIXED : 문자데이터 또는 자식엘리먼트를 혼합형태\n\t\t\t\t\tANY\n\n\t\t\t- ATTRIBUTE 선언\n\t\t\t\t<!ATTLIST 엘리먼트명 속성명 속성유형 디폴트선언>\n\t\t\t\t속성 유형\n\t\t\t\t\tCDATA\t: 문자 데이터\n\t\t\t\t\tENUMERATION\t: dtd에 나열된 값 중 하나가 와야 함\n\t\t\t\t\tID : 유일한 값을 지정\n\t\t\t\t\tIDREF/IDREFS : ID값을 참조\n\t\t\t\t\tNMTOKEN/NMTOKENS : 이름 작성 규칙을 준수하는 \n\t\t\t\t\t\t데이터만 사용\n\t\t\t\t\tNOTATION : dtd에 명시적으로 선언된 notation만 사용가능\n\t\t\t\t\tENTITY : dtd에 명시적으로 선언된 entity만 사용 가능\n\t\t\n\t\t(5) 네임 스페이스\n\t\t\tCML\n\t\t\t-----\n\t\t\t<?xml version=1.0>\n\t\t\t<정보>\n\t\t\t\t<고유번호>111111-1111111</고유번호>\n\t\t\t\t<이름>홍길동</이름>\n\t\t\t\t...\n\t\t\t</정보>\n\t\t\t\n\t\t\tPML\n\t\t\t-----\n\t\t\t<?xml version=1.0>\n\t\t\t<정보>\n\t\t\t\t<고유번호>LC100</고유번호>\n\t\t\t\t<이름>캠코더</이름>\n\t\t\t\t...\n\t\t\t</정보>\n\t\t\t\n\t\t\tOML\n\t\t\t-----\n\t\t\t<?xml version=1.0>\n\t\t\t<주문정보 xmlns:고객="http://www.a.com/2017/Custom"\n\t\t\t\txmlns:상품="http://www.a.com/2017/Product"\n\t\t\t\txmlns="http://www.a.com/2017/Order">\n\t\t\t\t<주문번호>1</주문번호>\n\t\t\t\t<주문수량>10</주문수량>\n\t\t\t\t<결제>\n\t\t\t\t\t<방법>현금</방법>\n\t\t\t\t\t<금액>10000000</금액>\n\t\t\t\t</결제>\n\t\t\t\t\n\t\t\t\t<고객:고유번호>111111-1111111</고객:고유번호>\n\t\t\t\t<고객:이름>홍길동</고객:이름>\n\t\t\t\t\n\t\t\t\t<상품:고유번호>LC100</상품:고유번호>\n\t\t\t\t<상품:이름>캠코더</상품:이름>\n\t\t\t\t...\n\t\t\t</주문정보>\n'

# %%
import xml.etree.ElementTree as elemTree

# %%
"""
XML을 pashing하는 방법
-----------------------
1. xml이 파일로 존재하는 경우 : parse()
2. xml이 문자열 형태로 존재하는 경우 : fromstring()
"""
# Out:
# '\nXML을 pashing하는 방법\n-----------------------\n1. xml이 파일로 존재하는 경우 : parse()\n2. xml이 문자열 형태로 존재하는 경우 : fromstring()\n'

# %%
tree = elemTree.parse("data/users.xml")
tree

# %%
xmlstr= """<?xml version="1.0" encoding="utf-8" ?>
<users>
	<user grade="gold">
            <name>Kim Cheol Soo</name>
            <age>25</age>
            <birthday>19940215</birthday>
        </user>
        <user grade="diamond">
            <name>Kim Yoo Mee</name>
            <age>21</age>
            <birthday>19980417</birthday>
        </user>
</users>
"""

tree = elemTree.fromstring(xmlstr)
tree
# Out:
# <Element 'users' at 0x00000192C50FA9A8>

# %%
# 태그 검색 및 데이터 다루기

#user = tree.find("user")
user = tree.find("user[1]")

user
# Out:
# <Element 'user' at 0x00000192C50BEF98>

# %%
dir(user)
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'attrib',
#  'clear',
#  'extend',
#  'find',
#  'findall',
#  'findtext',
#  'get',
#  'getchildren',
#  'getiterator',
#  'insert',
#  'items',
#  'iter',
#  'iterfind',
#  'itertext',
#  'keys',
#  'makeelement',
#  'remove',
#  'set',
#  'tag',
#  'tail',
#  'text']

# %%
print(user.tag)
print(user.attrib)
print(user.get("grade"))

print("========================")

name= user.find("name")
print(name.text)

age= user.find("age")
print(age.text)
# Out:
# user
# {'grade': 'gold'}
# gold
# ========================
# Kim Cheol Soo
# 25

# %%
# 여러개의 태그를 한꺼번에 가져오기
users = tree.findall("user")
users

for user in users : 
    print(user.attrib)
# Out:
# {'grade': 'gold'}
# {'grade': 'diamond'}

# %%
tree
# Out:
# <Element 'users' at 0x00000192C50FA9A8>

# %%
tree= elemTree.parse("data/users.xml")
users = tree.getroot()
print(users.tag)
print(users.attrib)



user = users.find("user")
print(user)
print(user.get("grade"))
print(user.keys())
print(user.items())
# Out:
# users
# {}
# <Element 'user' at 0x00000192C5130458>
# gold
# ['grade']
# [('grade', 'gold')]

# %% [markdown]
# ## JSON (JavaScript Object Notation)
#
#     dumps : 데이터를 저장할 때
#     loads : 데이터를 불러올 때

# %%
import json

# %%
j1 = {"name":"홍길동", "birth":"0524", "age":20}
print(type(j1))
print(j1)

j2=json.dumps(j1)
print(type(j2))
print(j2)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0524', 'age': 20}
# <class 'str'>
# {"name": "\ud64d\uae38\ub3d9", "birth": "0524", "age": 20}

# %%
json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
j3 = json.loads(j2)
print(type(j3))
print(j3)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0524', 'age': 20}

# %%
obj = """
{
"id": "0001",
"type": "donut",
"name": "Cake",
"ppu": 0.55,
"batters":
{
"batter":
[
{ "id": "1001", "type": "Regular" },
{ "id": "1002", "type": "Chocolate" },
{ "id": "1003", "type": "Blueberry" },
{ "id": "1004", "type": "Devil's Food" }
]
},
"topping":
[
{ "id": "5001", "type": "None" },
{ "id": "5002", "type": "Glazed" },
{ "id": "5005", "type": "Sugar" },
{ "id": "5007", "type": "Powdered Sugar" },
{ "id": "5006", "type": "Chocolate with Sprinkles" },
{ "id": "5003", "type": "Chocolate" },
{ "id": "5004", "type": "Maple" }
]
}
"""

type(obj)
# Out:
# str

# %%
result = json.loads(obj)
type(result)
result["id"]
result["batters"]["batter"][0]["id"]
# Out:
# '1001'

# %% [markdown]
# ### 웹소스 읽기

# %%
from urllib.request import urlopen

# %%
html = urlopen("http://google.com")
print(type(html))
print(html.read())
# Out:
# <class 'http.client.HTTPResponse'>
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="FXY5REabkKQ3thEEmpObGg==">(function(){window.google={kEI:\'S87iXuTcNMal-QbFzayYBw\',kEXPI:\'0,18168,183955,3,4,32,1100063,51521,5663,731,223,5105,206,3204,10,1226,364,1499,576,36,205,383,246,5,1307,47,196,790,708,99,1118,634,333,4,133,138,145,116,3,75,263,63,325,1122623,1197790,101,258,78,329040,1294,12383,4855,32691,15248,867,28684,9188,8384,4858,1362,9291,3029,4738,2136,7081,1816,1808,4020,978,7931,5297,2054,920,873,1217,1710,1,1264,2693,3737,11306,3222,234,4283,1396,1381,919,2277,9,84,2711,1595,1277,2213,238,291,149,1103,840,517,1522,157,635,3466,312,1137,2,2669,1839,184,2297,1947,2229,93,328,1284,16,2927,2246,474,1339,748,1039,3228,2844,7,4811,788,469,6286,4454,642,2449,2459,1226,1743,3654,1274,108,3407,908,2,941,532,440,1642,2397,1386,1510,2523,2051,840,1337,1098,3,346,230,970,865,372,3546,706,149,189,1666,1647,802,1687,27,2223,1993,1997,1101,643,4,1336,192,17,924,354,1009,1236,271,874,395,2,8,41,1799,20,1520,906,503,41,297,195,732,42,250,1075,91,254,1630,45,75,1223,212,499,640,591,1594,742,1,252,425,1588,86,3,585,19,148,741,237,1024,526,1418,8,69,93,745,95,1317,329,36,42,328,232,621,523,54,753,12,246,1772,14,471,186,55,1372,541,2,26,895,3,1,52,35,6,156,105,25,915,91,2,5803388,3375,79,1802439,4194806,2801216,549,333,444,1,2,80,1,900,896,1,8,1,2,2551,1,748,141,59,736,563,1,4265,1,1,1,1,137,1,879,9,305,2529,176,1,8,3,3389561,20572126,40,2682692\',kBL:\'P2-H\'};google.sn=\'webhp\';google.kHL=\'ko\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(b);a.src=b;google.li=f+1}};google.logUrl=function(a,c,b,d,g){var e="",f=google.ls||"";b||-1!=c.search("&ei=")||(e="&ei="+google.getEI(d),-1==c.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!b&&google.cshid&&-1==c.search("&cshid=")&&"slh"!=a&&(d="&cshid="+google.cshid);b=b||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+c+e+f+"&zx="+google.time()+d;/^http:/i.test(b)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:b,glmm:1}),b="");return b};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:a ...

# %%
from urllib.error import HTTPError, URLError
try : 
    
    html = urlopen("https://naver.com/index.jsp")
except HTTPError as err :
    print("Http 에러입니다." + str(err))
except URLError as err :
    print("URL 에러입니다." + str(err))    
else :    
    print(html.read())
# Out:
# Http 에러입니다.HTTP Error 404: Not Found

# %%
# 이미지 다운로드
from urllib.request import urlretrieve

urlretrieve("https://t1.daumcdn.net/daumtop_chanel/op/20170315064553027.png",
           "data/daum.png")
print("저장되었습니다.")
# Out:
# 저장되었습니다.

# %%
img = urlopen("https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png")
img = img.read()

f = open("data/google.png", "wb")
f.write(img)
f.close()
print("저장되었습니다.")
# Out:
# 저장되었습니다.

# %%
import urllib.parse

api = "http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp"
value = {"stnId":109}

params = urllib.parse.urlencode(value)
params

url = api + "?" + params
url

data=urlopen(url).read()
# print(data)
data = data.decode("utf-8")
print(data)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2020년 06월 12일 (금)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2020년 06월 12일 (금)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202006120600</tm>
# 		<wf><![CDATA[○ (기온) 15일(월)~22일(월) 낮 기온은 25~32도로 어제(11일, 29~34도)보다 조금 낮겠습니다. 16일(화)부터 21일(일)까지 낮 기온은 30도 내외까지 올라 덥겠습니다. <br />○ (해상) 서해중부해상 물결은 0.5~2.0m로 일겠습니다.<br />○ (주말전망) 13일(토)은 흐리고 저녁부터 비가 오겠고, 14일(일) 흐린 후 낮부터 맑아지겠고, 오전까지 비가 오겠습니다. 아침 기온은 17~22도, 낮 기온은 24~32도의 분포가 되겠습니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>백령도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>과천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광명</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>강화</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>24</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>24</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>김포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>시흥</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>부천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>21</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의정부</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>고양</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>양주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>동두천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# ...
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의왕</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>15</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>15</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>군포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>20</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>용인</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>여주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-15 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-16 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>16</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>17</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-06-19 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>19</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-06-22 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %% [markdown]
# ### BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
page = open("data/test_first.html").read()
print(type(page))

soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <class 'str'>
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html><head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
list(soup.children)
list(soup.children)[0]
list(soup.children)[1]
list(soup.children)[2]
# Out:
# <html><head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
html = list(soup.children)[2]

# %%
list(html.children)
# Out:
# [<head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>,
#  '\n',
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>,
#  '\n']

# %%
body = list(html.children)[2]
body
html.body
soup.html.body
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
# 태그명으로 접근
soup.find("p")
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# 태그명과 클래스명으로 접근
soup.find_all("p",class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
#id로 접근
soup.find_all(id="second")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>]

# %%
# next_sibling을 통해 soup의 head 다음에 줄바꿈 문자가 있다는 것을 알 수 있다.
soup.head.next_sibling
# Out:
# '\n'

# %%
# head와 같은 위치에 있던 body 태그로 접근하는 방법
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# 데이터 (Text Node) 가져오기
soup.html.get_text()
soup.head.get_text()
soup.title.get_text()
soup.div.get_text()

soup.p.get_text()

for p in soup.find_all("p"):
    print(p.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
# 속성값에 접근하기
links = soup.find('a')
links
links['href']

links = soup.find_all('a')
for link in links:
    href = link['href']
    text = link.string
    print(text, '=>', href)
# Out:
# PinkWink => http://www.pinkwink.kr
# Python => https://www.python.org

# %% [markdown]
# ## 실습

# %%
# 네이버 환율 정보 가져오기
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
span = soup.find_all('span',class_="value")
print("미 환율 : ", span[0].get_text())

div= soup.find_all("div", class_="head_info")
span1=div[0].find_all("span")
span1
print( span[0].get_text())

span2=soup.select_one("div.head_info > span.value").string
print(span2)
# Out:
# 미 환율 :  1,208.10
# 1,208.10
# 1,208.10

# %%
# 윤동주 시인의 작품을 추출
url = "https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

div = soup.find_all("div", class_="mw-parser-output")
ul = div[0].find_all("ul")
ul1 = ul[0].find_all("ul")
ul1
# Out:
# [<ul><li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%84%9C%EC%8B%9C" title="하늘과 바람과 별과 시/서시">서시</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%9E%90%ED%99%94%EC%83%81" title="하늘과 바람과 별과 시/자화상">자화상</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%86%8C%EB%85%84" title="하늘과 바람과 별과 시/소년">소년</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%88%88_%EC%98%A4%EB%8A%94_%EC%A7%80%EB%8F%84" title="하늘과 바람과 별과 시/눈 오는 지도">눈 오는 지도</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%8F%8C%EC%95%84%EC%99%80_%EB%B3%B4%EB%8A%94_%EB%B0%A4" title="하늘과 바람과 별과 시/돌아와 보는 밤">돌아와 보는 밤</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%B3%91%EC%9B%90" title="하늘과 바람과 별과 시/병원">병원</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%83%88%EB%A1%9C%EC%9A%B4_%EA%B8%B8" title="하늘과 바람과 별과 시/새로운 길">새로운 길</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EA%B0%84%ED%8C%90_%EC%97%86%EB%8A%94_%EA%B1%B0%EB%A6%AC" title="하늘과 바람과 별과 시/간판 없는 거리">간판 없는 거리</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%ED%83%9C%EC%B4%88%EC%9D%98_%EC%95%84%EC%B9%A8" title="하늘과 바람과 별과 시/태초의 아침">태초의 아침</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%98%90_%ED%83%9C%EC%B4%88%EC%9D%98_%EC%95%84%EC%B9%A8" title="하늘과 바람과 별과 시/또 태초의 아침">또 태초의 아침</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%83%88%EB%B2%BD%EC%9D%B4_%EC%98%AC_%EB%95%8C%EA%B9%8C%EC%A7%80" title="하늘과 바람과 별과 시/새벽이 올 때까지">새벽이 올 때까지</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%AC%B4%EC%84%9C%EC%9A%B4_%EC%8B%9C%EA%B0%84" title="하늘과 바람과 별과 시/무서운 시간">무서운 시간</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%8B%AD%EC%9E%90%EA%B0%80" title="하늘과 바람과 별과 시/십자가">십자가</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%B0%94%EB%9E%8C%EC%9D%B4_%EB%B6%88%EC%96%B4" title="하늘과 바람과 별과 시/바람이 불어">바람이 불어</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%8A%AC%ED%94%88_%EC%A1%B1%EC%86%8D" title="하늘과 바람과 별과 시/슬픈 족속">슬픈 족속</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%88%88%EA%B0%90%EA%B3%A0_%EA%B0%84%EB%8B%A4" title="하늘과 바람과 별과 시/눈감고 간다">눈감고 간다</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%98%90_%EB%8B%A4%EB%A5%B8_%EA%B3%A0%ED%96%A5" title="하늘과 바람과 별과 시/또 다른 고향">또 다른 고향</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EA%B8%B8" title="하늘과 바람과 별과 시/길">길</a></li>
#  <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%B3%84_%ED%97%A4%EB%8A%94_%EB%B0%A4" title="하늘과 바람과 별과 시/별 헤는 밤">별 헤는 밤</a></li></ul>]

# %%
for i in ul1[0] :
    if i != "\n":
        print(i.string)
# Out:
# 서시
# 자화상
# 소년
# 눈 오는 지도
# 돌아와 보는 밤
# 병원
# 새로운 길
# 간판 없는 거리
# 태초의 아침
# 또 태초의 아침
# 새벽이 올 때까지
# 무서운 시간
# 십자가
# 바람이 불어
# 슬픈 족속
# 눈감고 간다
# 또 다른 고향
# 길
# 별 헤는 밤

# %%
url = "http://www.pythonscraping.com/pages/warandpeace.html"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
# 녹색 단어만 골라오기
#green = soup.find_all("span", class_="green")
#for g in green:
#    print(g.string)
    
green = soup.select("div#text > span.green")
for g in green:
    print(g.string)
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
green = soup.find_all("span",{"class":"green"})   # 모든 스팬을 조사
for g in green:
    print(g.string)
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
#h태그 - > 제목 등 표시할때 크게
#h태그를 이용한 제목 추출
titles = soup.find_all(["h1","h2"])
print(titles)
print([title.get_text() for title in titles])
# Out:
# [<h1>War and Peace</h1>, <h2>Chapter 1</h2>]
# ['War and Peace', 'Chapter 1']

# %%
# 녹색과 적색 단어 추출
green_red = soup.find_all("span", {"class":{"green", "red"}})
print([text.string for text in green_red])
# Out:
# ["Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.", 'Anna\nPavlovna Scherer', 'Empress Marya\nFedorovna', 'Prince Vasili Kuragin', 'Anna Pavlovna', 'St. Petersburg', 'If you have nothing better to do, Count [or Prince], and if the\nprospect of spending an evening with a poor invalid is not too\nterrible, I shall be very charmed to see you tonight between 7 and 10-\nAnnette Scherer.', 'Heavens! what a virulent attack!', 'the prince', 'Anna Pavlovna', "First of all, dear friend, tell me how you are. Set your friend's\nmind at rest,", 'Can one be well while suffering morally? Can one be calm in times\nlike these if one has any feeling?', 'Anna Pavlovna', 'You are\nstaying the whole evening, I hope?', "And the fete at the English ambassador's? Today is Wednesday. I\nmust put in an appearance there,", 'the prince', 'My daughter is\ncoming for me to take me there.', "I thought today's fete had been canceled. I confess all these\nfestivities and fireworks are becoming wearisome.", 'If they had known that you wished it, the entertainment would\nhave been put off,', 'the prince', "Don't tease! Well, and what has been decided about Novosiltsev's\ndispatch? You know everything.", 'What can one say about it?', 'the prince', 'What has been decided? They have decided that\nBuonaparte has burnt his boats, and I believe that we are ready to\nburn ours.', 'Prince Vasili', 'Anna Pavlovna', 'Anna Pavlovna', "Oh, don't speak to me of Austria. Perhaps I don't understand\nthings, but Austria never has wished, and does not wish, for war.\nShe is betraying us! Russia alone must save Europe. Our gracious\nsovereign recognizes his high vocation and will be true to it. That is\nthe one thing I have faith in! Our good and wonderful sovereign has to\nperform the noblest role on earth, and he is so virtuous and noble\nthat God will not forsake him. He will fulfill his vocation and\ncrush the hydra of revolution, which has become more terrible than\never in the person of this murderer and villain! We alone must\navenge the blood of the just one.... Whom, I ask you, can we rely\non?... England with her commercial spirit will not and cannot\nunderstand the Emperor Alexander's loftiness of soul. She has\nrefused to evacuate Malta. She wanted to find, and still seeks, some\nsecret motive in our actions. What answer did Novosiltsev get? None.\nThe English have not understood and cannot understand the\nself-abnegation of our Emperor who wants nothing for himself, but only\ndesires the good of mankind. And what have they promised? Nothing! And\nwhat little they have promised they will not perform! Prussia has\nalways declared that Buonaparte is invincible, and that all Europe\nis powerless before him.... And I don't believe a word that Hardenburg\nsays, or Haugwitz either. This famous Prussian neutrality is just a\ntrap. I have faith only in God and the lofty destiny of our adored\nmonarch. He will save Europe!", 'I think,', 'the prince', None, 'Wintzingerode', 'King of Prussia', 'In a moment. A propos,', None, 'le Vicomte de Mortemart', 'Montmorencys', 'Rohans', 'Abbe Morio', 'the Emperor', 'I shall be delighted to meet them,', 'the prince', 'But tell me,', 'is it true that the Dowager Empress wants Baron Funke\nto be appointed first secretary at Vienna? The baron by all accounts\nis a poor creature.', 'Prince Vasili', 'Dowager Empress Marya Fedorovna', 'the baron', 'Anna Pavlovna', 'the Empress', 'Baron Funke has been recommended to the Dowager Empress by her\nsister,', 'the Empress', "Anna Pavlovna's", 'Her Majesty', 'Baron\nFunke', 'The prince ...

# %%
url = "http://www.pythonscraping.com/pages/page3.html"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

# 제목행을 건너 뛰고 나머지 모든 행 추출
#for tr in soup.find("table", {"id":"giftList"}).tr.next_siblings:
#    print(tr)
# 가격 중에 $15.00 수집
td = soup.find("tr", id="gift1").td.next_sibling.next_sibling
td.get_text()

td1 = soup.find("img", {"src":"../img/gifts/img1.jpg"}).parent.previous_sibling
td1.get_text()
# Out:
# '\n$15.00\n'

# %%
# 영화 리뷰
review_list = []

for i in range(1, 6):
    target = urlopen("https://movie.daum.net/moviedb/grade?movieId=94484&type=netizen&page={}".format(i))
    soup = BeautifulSoup(target, "html.parser")
    
    reviews = soup.select("p.desc_review")
    for review in reviews:
        str = review.get_text().strip()
        review_list.append(str)
        
f = open("data/아쿠아맨.txt", "w")
for review in review_list:
    f.write(review + "\n")
            
f.close()

# %%
url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20170806"
page = urlopen(url)
soup = BeautifulSoup(page,"html.parser")

# %%
# 영화 제목 추출
divs = soup.find_all('div', {'class' : 'tit5'})
## 요곤 내가 한거
title = []
for div in divs:
    title.append(div.find('a').get_text())
## 강사님
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '다크 나이트'

# %%
# 평점 추출
soup.find_all('td', {'class' : 'point'})[0].string
soup.find_all('td', 'point')[0].string
# Out:
# '9.32'

# %%
# 영화 제목과 평점을 각 리스트 변수에 저장
movie_name = [soup.find_all('div', {'class' : 'tit5'})[n].a.string for n in range(0, 47)]
movie_point = [soup.find_all('td', 'point')[n].string for n in range(0, 47)]

movie_name
movie_point
# Out:
# ['9.32',
#  '9.27',
#  '9.25',
#  '9.24',
#  '9.23',
#  '9.23',
#  '9.21',
#  '9.20',
#  '9.18',
#  '9.14',
#  '9.10',
#  '9.10',
#  '9.09',
#  '9.08',
#  '9.05',
#  '9.05',
#  '9.02',
#  '9.00',
#  '8.93',
#  '8.91',
#  '8.90',
#  '8.87',
#  '8.86',
#  '8.83',
#  '8.76',
#  '8.75',
#  '8.73',
#  '8.70',
#  '8.62',
#  '8.59',
#  '8.58',
#  '8.48',
#  '8.48',
#  '8.47',
#  '8.39',
#  '8.34',
#  '8.32',
#  '8.12',
#  '7.97',
#  '7.84',
#  '7.39',
#  '7.26',
#  '6.97',
#  '6.59',
#  '6.09',
#  '5.17',
#  '5.00']

# %%
# 2017년 5월 1일 부터 100일간의 데이터 수집

date = pd.date_range('20170501', periods = 100, freq = 'D')   # freq : 생략 가능
date

from tqdm import tqdm_notebook
import urllib


movie_date = []
movie_name = []
movie_point = []

for today in date:
    url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={}"
    page = urlopen(url.format(urllib.parse.quote(today.strftime("%Y%m%d"))))
    soup = BeautifulSoup(page, "html.parser")
    
    cnt = len(soup.find_all("td","point"))
    
    movie_date.extend([today for n in range(0, cnt)])
    movie_name.extend([soup.find_all('div', {'class' : 'tit5'})[n].a.string for n in range(0, cnt)])
    movie_point.extend(soup.find_all('td', 'point')[n].string for n in range(0, cnt))

# %%
movie_name
# Out:
# ['히든 피겨스',
#  '사운드 오브 뮤직',
#  '시네마 천국',
#  '미스 슬로운',
#  '잉여들의 히치하이킹',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '벤허',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '로건',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '시카고',
#  '10분',
#  '해리가 샐리를 만났을 때',
#  '미녀와 야수',
#  '너의 이름은.',
#  '그랑블루',
#  '한공주',
#  '연애담',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '스머프: 비밀의 숲',
#  '부당거래',
#  '파닥파닥',
#  '아비정전',
#  '패션 오브 크라이스트',
#  '라라랜드',
#  '뽀로로 극장판 슈퍼썰매 대모험',
#  '족구왕',
#  '가디언즈 오브 갤럭시',
#  '자전거 탄 소년',
#  '오두막',
#  '성실한 나라의 앨리스',
#  '원라인',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '임금님의 사건수첩',
#  '문라이트',
#  '로미오와 줄리엣',
#  '히든 피겨스',
#  '사운드 오브 뮤직',
#  '시네마 천국',
#  '미스 슬로운',
#  '잉여들의 히치하이킹',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '벤허',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '시카고',
#  '10분',
#  '해리가 샐리를 만났을 때',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '한공주',
#  '연애담',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '행복 목욕탕',
#  '스머프: 비밀의 숲',
#  '부당거래',
#  '파닥파닥',
#  '아비정전',
#  '패션 오브 크라이스트',
#  '라라랜드',
#  '뽀로로 극장판 슈퍼썰매 대모험',
#  '족구왕',
#  '가디언즈 오브 갤럭시',
#  '오두막',
#  '성실한 나라의 앨리스',
#  '원라인',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '문라이트',
#  '임금님의 사건수첩',
#  '로미오와 줄리엣',
#  '인생은 아름다워',
#  '레옹',
#  '히든 피겨스',
#  '사운드 오브 뮤직',
#  '피아니스트',
#  '시네마 천국',
#  '미스 슬로운',
#  '잉여들의 히치하이킹',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '벤허',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '보스 베이비',
#  '시카고',
#  '비포 선라이즈',
#  '10분',
#  '해리가 샐리를 만났을 때',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '한공주',
#  '연애담',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '비포 선셋',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '행복 목욕탕',
#  '부당거래',
#  '스머프: 비밀의 숲',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '아비정전',
#  '라라랜드',
#  '오두막',
#  '족구왕',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '티파니에서 아침을',
#  '존 윅 - 리로드',
#  '히든 피겨스',
#  '사운드 오브 뮤직',
#  '미스 슬로운',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '댄서',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '10분',
#  '보스 베이비',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '한공주',
#  '연애담',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '분노',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '스머프: 비밀의 숲',
#  '악마는 프라다를 입는다',
#  '오두막',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '원라인',
#  '사일런스',
#  '아빠는 딸',
#  '클로저',
#  '임금님의 사건수첩',
#  '문라이트',
#  '특별시민',
#  '프리즌',
#  '파워레인져스: 더 비기닝',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '서서평, 천천히 평온하게',
#  '히든 피겨스',
#  '사운드 오브 뮤직',
#  '미스 슬로운',
#  '나, 다니엘 블레이크',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '10분',
#  '미녀와 야수',
#  '보스 베이비',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '연애담',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '오두막',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '사일런스',
#  '원라인',
#  '아빠는 딸',
#  '클로저',
#  '임금님의 사건수첩',
#  '문라이트',
#  '특별시민',
#  '프리즌',
#  '파워레인져스: 더 비기닝',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '서서평, 천천히 평온하게',
#  '히든 피겨스',
#  '사운드 오브 뮤직',
#  '미스 슬로운',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '10분',
#  '미녀와 야수',
#  '보스 베이비',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '오두막',
#  '스머프: 비밀의 숲',
#  '악마는 프라다를 입는다',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '사일런스',
#  '원라인',
#  '아빠는 딸',
#  '클로저',
#  '임금님의 사건수첩',
#  '문라이트',
#  '프리즌',
#  '특별시민',
#  '파워레인져스: 더 비기닝',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '서서평, 천천히 평온하게',
#  '히든 피겨스',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '미스 슬로운',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '미녀와 야수',
#  '너의 이름은.',
#  '보스 베이비',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '오두막',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '가디언즈 오브 갤럭시',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '원라인',
#  '사일런스',
#  '아빠는 딸',
#  '클로저',
#  '문라이트',
#  '임금님의 사건수첩',
#  '프리즌',
#  '특별시민',
#  '파워레인져스: 더 비기닝',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '서서평, 천천히 평온하게',
#  '히든 피겨스',
#  '시네마 천국',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '말할 수 없는 비밀',
#  '미스 슬로운',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '물랑 루즈',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '싱 스트리트',
#  '시카고',
#  '10분',
#  '미녀와 야수',
#  '너의 이름은.',
#  '보스 베이비',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '오두막',
#  '행복 목욕탕',
#  '부당거래',
#  '오페라의 유령',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '원라인',
#  '사일런스',
#  '아빠는 딸',
#  '클로저',
#  '문라이트',
#  '임금님의 사건수첩',
#  '서서평, 천천히 평온하게',
#  '히든 피겨스',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '미스 슬로운',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '더 플랜',
#  '분노의 질주: 더 익스트림',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '보스 베이비',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '오두막',
#  '분노',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '목소리의 형태',
#  '에이리언: 커버넌트',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '보안관',
#  '성실한 나라의 앨리스',
#  '존 윅 - 리로드',
#  '원라인',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '문라이트',
#  '석조저택 살인사건',
#  '임금님의 사건수첩',
#  '프리즌',
#  '파워레인져스: 더 비기닝',
#  '특별시민',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '보스 베이비',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '연애담',
#  '오두막',
#  '분노',
#  '발레리나',
#  '맨체스터 바이 더 씨',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '에이리언: 커버넌트',
#  '라라랜드',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '목소리의 형태',
#  '성실한 나라의 앨리스',
#  '보안관',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '석조저택 살인사건',
#  '문라이트',
#  '임금님의 사건수첩',
#  '프리즌',
#  '파워레인져스: 더 비기닝',
#  '특별시민',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '바람과 함께 사라지다',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '보스 베이비',
#  '연애담',
#  '오두막',
#  '발레리나',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '에이리언: 커버넌트',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '목소리의 형태',
#  '성실한 나라의 앨리스',
#  '보안관',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '문라이트',
#  '임금님의 사건수첩',
#  '석조저택 살인사건',
#  '프리즌',
#  '파워레인져스: 더 비기닝',
#  '특별시민',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '한공주',
#  '그랑블루',
#  '연애담',
#  '보스 베이비',
#  '오두막',
#  '발레리나',
#  '분노',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '에이리언: 커버넌트',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '목소리의 형태',
#  '성실한 나라의 앨리스',
#  '보안관',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '문라이트',
#  '임금님의 사건수첩',
#  '석조저택 살인사건',
#  '종이 달',
#  '프리즌',
#  '특별시민',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '오즈의 마법사',
#  '우리들',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '한공주',
#  '오두막',
#  '연애담',
#  '보스 베이비',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '맨체스터 바이 더 씨',
#  '발레리나',
#  '분노',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '성실한 나라의 앨리스',
#  '보안관',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '아빠는 딸',
#  '문라이트',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '공각기동대 : 고스트 인 더 쉘',
#  '히든 피겨스',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '서서평, 천천히 평온하게',
#  '나, 다니엘 블레이크',
#  '댄서',
#  '일 포스티노',
#  '라이언',
#  '코알라',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '10분',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '오두막',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '한공주',
#  '보스 베이비',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '발레리나',
#  '분노',
#  '맨체스터 바이 더 씨',
#  '행복 목욕탕',
#  '부당거래',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '족구왕',
#  '가디언즈 오브 갤럭시',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '성실한 나라의 앨리스',
#  '보안관',
#  '존 윅 - 리로드',
#  '사일런스',
#  '클로저',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '콜로설',
#  '레옹',
#  '죽은 시인의 사회',
#  '히든 피겨스',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '서서평, 천천히 평온하게',
#  '나, 다니엘 블레이크',
#  '댄서',
#  '일 포스티노',
#  '라이언',
#  '다음 침공은 어디?',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '8 마일',
#  '미녀와 야수',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '오두막',
#  '그랑블루',
#  '보스 베이비',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '발레리나',
#  '맨체스터 바이 더 씨',
#  '분노',
#  '행복 목욕탕',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '페인티드 베일',
#  '족구왕',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '티파니에서 아침을',
#  '존 윅 - 리로드',
#  '보안관',
#  '사일런스',
#  '클로저',
#  '피아니스트',
#  '문라이트',
#  '라붐',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '공각기동대 : 고스트 인 더 쉘',
#  '밤의 해변에서 혼자',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '댄서',
#  '일 포스티노',
#  '라이언',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '8 마일',
#  '미녀와 야수',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '오두막',
#  '그랑블루',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '보스 베이비',
#  '발레리나',
#  '맨체스터 바이 더 씨',
#  '분노',
#  '행복 목욕탕',
#  '파닥파닥',
#  '악마는 프라다를 입는다',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '페인티드 베일',
#  '족구왕',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '존 윅 - 리로드',
#  '사일런스',
#  '보안관',
#  '클로저',
#  '피아니스트',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '밤의 해변에서 혼자',
#  '콜로설',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '나, 다니엘 블레이크',
#  '댄서',
#  '일 포스티노',
#  '물랑 루즈',
#  '라이언',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '본 슈프리머시',
#  '8 마일',
#  '불한당: 나쁜 놈들의 세상',
#  '미녀와 야수',
#  '너의 이름은.',
#  '오두막',
#  '메밀꽃, 운수 좋은 날, 그리고 봄봄',
#  '그랑블루',
#  '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국',
#  '보스 베이비',
#  '맨체스터 바이 더 씨',
#  '발레리나',
#  '분노',
#  '행복 목욕탕',
#  '오페라의 유령',
#  '파닥파닥',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '벨벳 골드마인',
#  '족구왕',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '목소리의 형태',
#  '에이리언: 커버넌트',
#  '겟 아웃',
#  '존 윅 - 리로드',
#  '사일런스',
#  '보안관',
#  '클로저',
#  '피아니스트',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '밤의 해변에서 혼자',
#  '히든 피겨스',
#  '피아니스트',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '말할 수 없는 비밀',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '나, 다니엘 블레이크',
#  '일 포스티노',
#  '댄서',
#  '물랑 루즈',
#  '라이언',
#  '분노의 질주: 더 익스트림',
#  '싱 스트리트',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '본 슈프리머시',
#  '시카고',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '오두막',
#  '그랑블루',
#  '보스 베이비',
#  '발레리나',
#  '맨체스터 바이 더 씨',
#  '분노',
#  '행복 목욕탕',
#  '오페라의 유령',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '벨벳 골드마인',
#  '자전거 탄 소년',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '목소리의 형태',
#  '에이리언: 커버넌트',
#  '존 윅 - 리로드',
#  '사일런스',
#  '신은 죽지 않았다 2',
#  '클로저',
#  '보안관',
#  '킹 아서: 제왕의 검',
#  '겟 아웃',
#  '피아니스트',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '히든 피겨스',
#  '피아니스트',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '나, 다니엘 블레이크',
#  '일 포스티노',
#  '댄서',
#  '라이언',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '본 슈프리머시',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '오두막',
#  '그랑블루',
#  '보스 베이비',
#  '발레리나',
#  '맨체스터 바이 더 씨',
#  '분노',
#  '행복 목욕탕',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '벨벳 골드마인',
#  '자전거 탄 소년',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '존 윅 - 리로드',
#  '사일런스',
#  '신은 죽지 않았다 2',
#  '클로저',
#  '보안관',
#  '겟 아웃',
#  '킹 아서: 제왕의 검',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '종이 달',
#  '석조저택 살인사건',
#  '특별시민',
#  '밤의 해변에서 혼자',
#  '불한당: 나쁜 놈들의 세상',
#  '히든 피겨스',
#  '피아니스트',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '나, 다니엘 블레이크',
#  '일 포스티노',
#  '댄서',
#  '원스 어폰 어 타임 인 아메리카',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '8 마일',
#  '미녀와 야수',
#  '너의 이름은.',
#  '오두막',
#  '그랑블루',
#  '보스 베이비',
#  '맨체스터 바이 더 씨',
#  '발레리나',
#  '행복 목욕탕',
#  '분노',
#  '스머프: 비밀의 숲',
#  '아비정전',
#  '라라랜드',
#  '벨벳 골드마인',
#  '자전거 탄 소년',
#  '미드나잇 인 파리',
#  '슈퍼 빼꼼: 스파이 대작전',
#  '에이리언: 커버넌트',
#  '목소리의 형태',
#  '존 윅 - 리로드',
#  '킹 아서: 제왕의 검',
#  '신은 죽지 않았다 2',
#  '사일런스',
#  '클로저',
#  '보안관',
#  '겟 아웃',
#  '문라이트',
#  '아빠는 딸',
#  '임금님의 사건수첩',
#  '석조저택 살인사건',
#  '특별시민',
#  '밤의 해변에서 혼자',
#  '불한당: 나쁜 놈들의 세상',
#  '히든 피겨스',
#  '서서평, 천천히 평온하게',
#  '흑집사 : 북 오브 더 아틀란틱',
#  '극장판 쿠로코의 농구 라스트 게임',
#  '나, 다니엘 블레이크',
#  '일 포스티노',
#  '댄서',
#  '원스 어폰 어 타임 인 아메리카',
#  '분노의 질주: 더 익스트림',
#  '더 플랜',
#  '가디언즈 오브 갤럭시 VOL. 2',
#  '8 마일',
#  ...]

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (4723, 4723, 4723)

# %%
movie = pd.DataFrame({'date' : movie_date, 'name' : movie_name, 'point' : movie_point})
movie.head()
# Out:
#         date        name point
# 0 2017-05-01      히든 피겨스  9.38
# 1 2017-05-01   사운드 오브 뮤직  9.36
# 2 2017-05-01      시네마 천국  9.29
# 3 2017-05-01      미스 슬로운  9.26
# 4 2017-05-01  잉여들의 히치하이킹  9.25

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4723 non-null   datetime64[ns]
#  1   name    4723 non-null   object
#  2   point   4723 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 110.8+ KB

# %%
movie["point"] = movie["point"].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4723 non-null   datetime64[ns]
#  1   name    4723 non-null   object
#  2   point   4723 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 110.8+ KB

# %%
# 영화별로 점수의 합계를 보고싶다 (합계가 높은 순으로 또는 낮은 순으로)
m_point= pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
m_point.head()
# Out:
#                point
# name
# 10분           124.46
# 47 미터         149.23
# 500일의 썸머       75.51
# 7년-그들이 없는 언론  137.28
# 7번째 내가 죽던 날   407.48

# %%
m_best = m_point.sort_values(by='point', ascending=False)
m_best.head(10)
# Out:
#                 point
# name
# 댄서             914.60
# 서서평, 천천히 평온하게  889.64
# 오두막            861.65
# 라라랜드           858.89
# 너의 이름은.        738.42
# 노무현입니다         682.24
# 보스 베이비         644.21
# 겟 아웃           630.62
# 기쿠지로의 여름       613.43
# 에이리언: 커버넌트     599.67

# %%
#특정 영화만 조회

tmp = movie.query('name==["겟 아웃"]')
tmp.head(10)
# Out:
#            date  name  point
# 833  2017-05-17  겟 아웃   8.36
# 889  2017-05-18  겟 아웃   8.18
# 933  2017-05-19  겟 아웃   8.20
# 980  2017-05-20  겟 아웃   8.18
# 1022 2017-05-21  겟 아웃   8.18
# 1061 2017-05-22  겟 아웃   8.11
# 1102 2017-05-23  겟 아웃   8.15
# 1146 2017-05-24  겟 아웃   8.15
# 1192 2017-05-25  겟 아웃   8.15
# 1236 2017-05-26  겟 아웃   8.16

# %%
plt.figure(figsize = (12, 8))
plt.plot(tmp['date'], tmp['point'])
plt.grid()

# %%
# 영화별 날짜 변화에 따른 평점 변화 확인
movie_pivot = pd.pivot_table(movie, index=["date"], columns=["name"], values=["point"])
movie_pivot.head()
# Out:
#            point                                                        \
# name         10분 47 미터 500일의 썸머 7년-그들이 없는 언론 7번째 내가 죽던 날 7인의 사무라이 8 마일
# date
# 2017-05-01  8.89   NaN      NaN          NaN         NaN      NaN  NaN
# 2017-05-02  8.89   NaN      NaN          NaN         NaN      NaN  NaN
# 2017-05-03  8.89   NaN      NaN          NaN         NaN      NaN  NaN
# 2017-05-04  8.89   NaN      NaN          NaN         NaN      NaN  NaN
# 2017-05-05  8.89   NaN      NaN          NaN         NaN      NaN  NaN
#
#                                                 ...                         \
# name       가디언즈 오브 갤럭시 가디언즈 오브 갤럭시 VOL. 2 겟 아웃  ... 하울의 움직이는 성 하이큐!! 끝과 시작
# date                                            ...
# 2017-05-01        8.56                NaN  NaN  ...        NaN         NaN
# 2017-05-02        8.56                NaN  NaN  ...        NaN         NaN
# 2017-05-03         NaN               9.22  NaN  ...        NaN         NaN
# 2017-05-04         NaN               9.15  NaN  ...        NaN         NaN
# 2017-05-05         NaN               9.08  NaN  ...        NaN         NaN
#
#
# name         한공주 해리가 샐리를 만났을 때 핵소 고지 행복 목욕탕 헤드윅 환상의 빛 흑집사 : 북 오브 더 아틀란틱 히든 피겨스
# date
# 2017-05-01  8.78          8.89   NaN   8.70 NaN   NaN              9.20   9.38
# 2017-05-02  8.78          8.89   NaN   8.68 NaN   NaN              9.21   9.37
# 2017-05-03  8.78          8.89   NaN   8.70 NaN   NaN              9.22   9.38
# 2017-05-04  8.78           NaN   NaN   8.67 NaN   NaN              9.23   9.38
# 2017-05-05  8.78           NaN   NaN   8.69 NaN   NaN              9.24   9.37
#
# [5 rows x 204 columns]

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name         10분  47 미터  500일의 썸머  7년-그들이 없는 언론  7번째 내가 죽던 날  7인의 사무라이  8 마일  \
# date
# 2017-05-01  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-02  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-03  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-04  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-05  8.89    NaN       NaN           NaN          NaN       NaN   NaN
#
# name        가디언즈 오브 갤럭시  가디언즈 오브 갤럭시 VOL. 2  겟 아웃  ...  하울의 움직이는 성  \
# date                                               ...
# 2017-05-01         8.56                 NaN   NaN  ...         NaN
# 2017-05-02         8.56                 NaN   NaN  ...         NaN
# 2017-05-03          NaN                9.22   NaN  ...         NaN
# 2017-05-04          NaN                9.15   NaN  ...         NaN
# 2017-05-05          NaN                9.08   NaN  ...         NaN
#
# name        하이큐!! 끝과 시작   한공주  해리가 샐리를 만났을 때  핵소 고지  행복 목욕탕  헤드윅  환상의 빛  \
# date
# 2017-05-01          NaN  8.78           8.89    NaN    8.70  NaN    NaN
# 2017-05-02          NaN  8.78           8.89    NaN    8.68  NaN    NaN
# 2017-05-03          NaN  8.78           8.89    NaN    8.70  NaN    NaN
# 2017-05-04          NaN  8.78            NaN    NaN    8.67  NaN    NaN
# 2017-05-05          NaN  8.78            NaN    NaN    8.69  NaN    NaN
#
# name        흑집사 : 북 오브 더 아틀란틱  히든 피겨스
# date
# 2017-05-01               9.20    9.38
# 2017-05-02               9.21    9.37
# 2017-05-03               9.22    9.38
# 2017-05-04               9.23    9.38
# 2017-05-05               9.24    9.37
#
# [5 rows x 204 columns]

# %%
target_col = ['군함도', '택시운전사', '다크 나이트', '겟 아웃']
plt.figure(figsize = (12, 8))
plt.plot(movie_pivot[target_col])
plt.legend(target_col ,loc='best')
plt.grid()

# %% [markdown]
# ### 로그인을 해야 하는 경우
#     - http
#     - https

# %%
import requests

# %%
url = 'https://www.hanbit.co.kr/member/login_proc.php'
data = {'m_id' : 'netsong7', 
        'm_passwd' : 'xxx',
        'return_url' : 'http://www.hanbit.co.kr'}

session = requests.session()
res = session.post(url, data)
print(res.text)
# Out:
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><script>alert('해당 회원의 정보가 없습니다.\n아이디/패스워드를 확인해주세요.')</script><script>history.go(-1)</script>

# %%
url_my = 'https://www.hanbit.co.kr/myhanbit/myhanbit.html'
res2 = session.get(url_my)
print(res2.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <meta charset="utf-8"/>
# <title>한빛출판네트워크</title>
# <link rel="shortcut icon" href="https://www.hanbit.co.kr/images/common/hanbit.ico">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="한빛출판네트워크"/>
# <meta property="og:description" content="출판사, IT전문서, 대학교재, 경제경영, 어린이/유아, MAKE, 실용/여행, 전자책, 인터넷 강의"/>
# <meta property="og:image" content="https://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />
# <meta property="og:url" content="https://www.hanbit.co.kr/myhanbit/myhanbit.html"/>
# <link rel="canonical" href="https://www.hanbit.co.kr/myhanbit/myhanbit.html" />
# <meta name="keywords" content="책,전자책,ebook,출판사,동영상,콘텐츠,강의,자격증,대학교재" />
# <meta name="description" content="출판사, IT전문서, 대학교재, 경제경영, 어린이/유아, MAKE, 실용/여행, 전자책, 인터넷 강의" />
# <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0">
# <meta name="viewport" content="width=1260">
# <meta name="apple-mobile-web-app-capable" content="yes" />
# <meta name="naver-site-verification" content="01c29ed1852aecca7a48ac0c3e0869627bc512d8"/>
# <!-- <meta name="naver-site-verification" content="823ff8b8e7e3eb396c310703c2bbd731f48c1d9b"/> -->
# <link rel="stylesheet" href="/css/common.css?20190625102532" />
# <link href="/css/hover.css" rel="stylesheet" media="all">
# <link rel="stylesheet" href="/js/jquery.raty.css" />
# <script type="text/javascript" src="/js/jquery-latest.js"></script>
# <script type="text/javascript" src="/js/jquery-ui.js"></script>
# <script type="text/javascript" src="/js/jquery.event.drag-1.5.min.js"></script>
# <script type="text/javascript" src="/js/jquery.touchSlider.js"></script>
# <script type="text/javascript" src="/js/jquery.raty.js"></script>
# <script type="text/javascript" src="/js/main.js"></script>
# <script type="text/javascript" src="/lib/cheditor/cheditor.js"></script>
# <script type="text/javascript" src="/js/jquery.ui.datepicker-ko.js"></script>
# <script type="text/javascript" src="/js/engine.js"></script>
# <script type="text/javascript" src="/js/vue.js"></script>
#
# <!-- Google Analytics -->
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-47080738-1', 'hanbit.co.kr');
# ga('require', 'linkid', 'linkid.js');
# ga('send', 'pageview');
# </script>
# <!-- Google Analytics -->
#
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '406459623338891');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
#   src="https://www.facebook.com/tr?id=406459623338891&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
#
# <!-- Kakao Pixel Code -->
# <script type="text/javascript" charset="UTF-8" src="//t1.daumcdn.net/adfit/static/kp.js"></script>
# <script type="text/javascript">
#   kakaoPixel('3011392806152551233').pageView();
# </script>
# <!-- //Kakao Pixel Code -->
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-W9D5PM3"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <link rel="stylesheet" href="/css/layout-hanbit.css?20191130" />
# <link rel="stylesheet" href="/css/layout-member.css" />
# <link rel="stylesheet" href="/css/layout-network.css" />
# <link rel="stylesheet" href="/css/layout-store.css" />
# <link rel="stylesheet" href="/css/layout-myhanbit.css" />
# <link rel="stylesheet" href="/css/layout-event.css" />
# <!-- 메뉴 바로가기 -->
# <div id="quick_skip_menu">
#   <a href="#gnb" onclick="document.getElementById('gnb').tabIndex = -1;document.getElementById('gnb').focus();return false;"><span>메뉴 바로가기</span></a>
#   <a href="#top_search" onclick="view_hover('main_search_area','','show'), document.getElementById('top_search').tabIndex = -1;document.getElementById('top_search').focus();return false;"><span>검색 및 카테고리 바로가기</span></a>
#     <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>본문 바로가기</span></a>
#   </div>
# <!-- //메뉴 바로가기 -->
#
# <!-- header -->
# <header>
#   <!-- top menu -->
#   	<nav>
# 		<div id="wrap_nav">
# 			<ul class="top_brand">
# 				<li><a href="https://www.hanbit.co.kr/index.html" name="hanbit_network"><span>HOME</span></a></li>
# 				<li><a href="https://www.hanbit.co.kr/media/">한빛미디어</a></li>
# 				<li><a href="https://www.hanbit.co.kr/academy/">한빛아카데미</a></li>
# 				<li><a href="https://www.hanbit.co.kr/biz/">한빛비즈</a></li>
# 				<li><a href="https://www.hanbit.co.kr/life/">한빛라이프</a></li>
# 				<li><a href="https://www.hanbit.co.kr/edu/">한빛에듀</a></li>
# 				<li><a href="https://www.hanbit.co.kr/realtime/">리얼타임</a></li>
# 				<li><a href="https://www.hanbit.co.kr/textbook/" target="_blank">한빛정보교과서</a></li>
#         <li><a href="https://www.hanbit.co.kr/rent/" target="_blank">한빛대관서비스</a></li>
# 			</ul>
#
# 			<ul class="top_menu">
#                         	<li><a href="https://www.hanbit.co.kr/member/login.html" class="login">로그인</a></li>
# 				<li><a href="https://www.hanbit.co.kr/member/member_agree.html" class="join">회원가입</a></li>
# 				<li><a href="https://www.hanbit.co.kr/myhanbit/myhanbit.html" class="myhanbit">마이한빛</a></li>
# 				<li><a href="https://www.hanbit.co.kr/myhanbit/cart.html" class="cart">장바구니</a></li>
#             				<!-- <li class="top_menu_store"><a href="https://www.hanbit.co.kr/store/store_submain.html">STORE</a></li> -->
# 			</ul>
# 		</div>
# 	</nav>  <!-- //top menu -->
#
#   <div id="wrap_gnb">
#     <!-- logo -->
#     <h1><a href="https://www.hanbit.co.kr/index.html">한빛출판네트워크</a></h1>
#     <!-- //logo -->
#
#     <!-- Menu -->
#     <div id="gnb" name="gnb">
#       <ul>
#         <li><a href="https://www.hanbit.co.kr/brand/brand_submain.html" class="">BRAND</a></li>
#         <li><a href="https://www.hanbit.co.kr/channel/channel_submain.html" class="">Channel.H</a></li>
#         <li><a href="https://www.hanbit.co.kr/store/store_submain.html" class="">STORE</a></li>
#         <li><a href="https://www.hanbit.co.kr/support/help_info.html" class="">SUPPORT</a></li>
#         <li><a href="https://www.hanbit.co.kr/event/current/current_event_list.html" class="">EVENT</a></li>
#
#         <li id="top_search" class="search"><a href="javascript:;" onClick="view_hover('main_search_area','','show'); $('#keyword_str').focus();"><span>SERACH</span></a></li>
#       </ul>
#     </div>
#     <!-- //Menu -->
#
#     <!-- lnb -->
#     <div class="lnb" style="top:92px;">
#       <div class="lnb_area">
#       <!-- BRAND -->
#                       </div>
#     </div>
#     <!--// lnb -->
#   </div>
# </header>
# <!-- //header -->
#
# <!-- 메인 검색 및 카테고리 영역 -->
# <div id="main_search_area" class="fixed" style="display:none;">
#   <div class="msa_wrap">
#
#     <!-- 검색 -->
#     <div class="msa_srch_wrap">
#       <form onsubmit="return false;">
#       <fieldset class="msa_srch_field">
#         <legend>한빛출판네트워크 검색</legend>
#         <input title="검색어" autocomplete="off" class="srch_keyword" accesskey="s" type="text" name="keyword_str" id="keyword_str" v-model="keyword" @input="typeKeyword">
#         <input type="submit" class="srch_btn" style="cursor:pointer;" @click="clickSearch">
#       </fieldset>
#       </form>
#     </div>
#     <!-- //검색 -->
#
#     <!-- ① 인기검색어 -->
#     <div class="msa_srch_polular" v-if="showPopularKeyword === true">
#       <h2 class="tit">인기 검색어 <span>(최근 1개월간)</span></h2>
#         <div class="popula_box">
#           <ul class="left">
#             <li v-for="keyword in leftPopularKeywordList">
#               <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
#             </li>
#           </ul>
#           <ul class="right">
#             <li v-for="keyword in rightPopularKeywordList">
#               <a :class="keyword.bold" @click="clickPopularKeyword(keyword)">
#                   {{ keyword.number }} {{ keyword.bookName }}
#               </a>
#             </li>
#           </ul>
#         </div>
#     </div>
#     <!-- ① 인기검색어 -->
#
#     <!-- ② 검색결과/검색서제스쳔 -->
#     <div class="msa_srch_suggestion" v-if="showPopularKeyword === false">
#       <div class="sugg_left" v-if="bookList.length !== 0">
#         <h3 class="tit">BOOK</h3>
#         <ul class="books_list">
#           <li v-for="book in bookList" @mouseover="mouseOverBook(book.id)"><a @click="clickBookKeyword(book)"><p v-html="book.name"></p></a></li>
#         </ul>
#       </div>
#
#       <div class="sugg_right">
#         <div class="sugg_book" v-if="bookList.length !== 0">
#           <table class="sugg_book_detail">
#             <tr>
#               <td class="cover">
#                 <a @click="clickBookKeyword(bookSummary)">
#                   <img :src="bookSummary.imgUrl" class="b_cover">
#                 </a>
#               </td>
#               <td class="draft">
#                 <a @click="clickBookKeyword(bookSummary)" class="b_title"><strong v-html="bookSummary.originName"></strong></a>
#                 <p class="b_int">
#                 {{ bookSummary.author }} 지음<br />
#                 {{ bookSummary.publishingCompany }} | {{ bookSummary.date }}
#                 </p>
#                 <p class="b_type">
#                 <span>{{ bookSummary.bookType }}</span>
#                 </p>
#               </td>
#             </tr>
#           </table>
#         </div>
#
#         <div class="sugg_edu" v-if="educationList.length !== 0">
#           <h3 class="tit">EDUCATION</h3>
#           <ul class="edu_list">
#             <li v-for="education in educationList">&#149; <a @click="clickEducationKeyword(education)"><span v-html="education.title"></span></a></li>
#           </ul>
#         </div>
#
#         <div class="sugg_cont" v-if="contentList.length !== 0">
#           <h3 class="tit">CONTENTS</h3>
#           <ul class="cont_list">
#             <li v-for="content in contentList">&#149; <a @click="clickContentKeyword(content)"><span v-html="content.title"></span></a></li>
#           </ul>
#         </div>
#       </div>
#     </div>
#     <!-- //② 검색결과/검색서제스쳔 -->
#
#   <!-- 닫기 -->
#   <div class="msa_wrap_close">
#     <a href="javascript:;" onclick="view_hover('main_search_area','','hide')">닫기</a>
#   </div>
#   <!-- //닫기 -->
#
#   </div>
# </div>
#
# <!-- old // 구현시 필요없으면 삭제해도 됩니다.
# <script type="text/javascript">
#   function sch_smit(){
#     if(!$.trim($("#keyword_str").val()).length) {
#       alert("검색어를 입력해주세요");
#       $("#keyword_str").focus();
#       return false;
#     }else{
#       $("#gnbsearchfrm").attr("action","/search/search_list.html");
#       $("#gnbsearchfrm").submit();
#     }
#   }
# </script>
# -->
#
# <script type="text/javascript">
#     "use strict";
#
#     var common_top_search_vue = new Vue({
#         el: '#main_search_area',
#         data: {
#             //검색엔진 URL
#             searchProxyURL: "https://search.hanbit.co.kr",
#             //인기 검색어 show 여부
#             showPopularKeyword: true,
#             //사용자 검색 키워드
#             keyword: '',
#             //인기 검색어 리스트
#             popularKeywordList: [],
#             // 인기 검색어 리스트 (왼쪽)
#             leftPopularKeywordList: [],
#             // 인기 검색어 리스트 (오른쪽)
#             rightPopularKeywordList: [],
#             // 자동완성에서의 책 리스트
#             bookList: [],
#             // 자동완성에서의 책 정보
#             bookSummary: {
#                 'imgUrl': '',
#                 'link': '',
#                 'name': '',
#                 'author': '',
#                 'publishingCompany': '',
#                 'date': '',
#                 'bookType': ''
#             },
#             //에듀케이션 리스트
#             educationList: [],
#             //컨텐츠 리스트
#             contentList: []
#         },
#         created: function created() {
#             // 인기 검색어 조회
#             this.getPopularKeyword();
#         },
#         methods: {
#             /**
#              * 사용자가 검색 키워드를 입력할때 발생하는 이벤트
#              */
#             typeKeyword: function typeKeyword() {
#                 var self = this;
#                 var keyword = $("#keyword_str").val();
#
#                 if (keyword.length !== 0) {
#                     //자동완성어
#                     this.findAutocompleteResult(keyword);
#                 } else {
#                     //인기검색어
#                     self.showPopularKeyword = true;
#                 }
#             },
#
#             /**
#              * 인기검색어 조회
#              */
#             getPopularKeyword: function getPopularKeyword() {
#                 var self = this;
#                 this.popularKeywordList = [];
#                 $.get(this.searchProxyURL + "/querylog/popularKeyword").done(function (data) {
#                     if (data != null) {
#                         self.drawPopularKeyword(data);
#                     }
#                 });
#             },
#
#             /**
#              * 인기 검색어 그리기
#              */
#             drawPopularKeyword: function drawPopularKeyword(popularBooks) {
#                 var self = this;
#                 popularBooks.forEach(function (item) {
#                     var popularBook = {
#                         bookName: item.keyword
#                     };
#                     self.popularKeywordList.push(popularBook);
#                 });
#                 var number = 0;
#
#                 for (var _iterator = this.popularKeywordList, _isArray = Array.isArray(_iterator), _i = 0, _iterator = _isArray ? _iterator : _iterator[Symbol.iterator]();;) {
#                     var _ref;
#
#                     if (_isArray) {
#                         if (_i >= _iterator.length) break;
#                         _ref = _iterator[_i++];
#                     } else {
#                         _i = _iterator.next();
#                         if (_i.done) break;
#                         _ref = _i.value;
#                     }
#
#                     var keyword = _ref;
#                     number = number + 1;
#                     keyword.number = number.toString().length < 2 ? "0" + number : number;
#
#                     if (number > 5) {
#                         keyword.direction = "right";
#                         self.rightPopularKeywordList.push(keyword);
#                     } else {
#                         keyword.direction = "left";
#
#                         if (number < 4) {
#                             keyword.bold = 'active';
#                         }
#
#                         self.leftPopularKeywordList.push(keyword);
#                     }
#                 }
#             },
#
#             /**
#              * 자동완성 검색 결과
#              */
#             findAutocompleteResult: function findAutocompleteResult(keyword) {
#                 var self = this;
#                 var param = {
#                     q: keyword,
#                     types: "education,book,contents",
#                     fq: keyword
#                 };
#                 $.post(this.searchProxyURL + "/autocomplete/search", param).done(function (data) {
#                     if (data != null) {
#                         var bookResult = data.booksResults;
#                         self.changeBookList(keyword, bookResult);
#                         var contentResult = data.contentsResults;
#                         self.changeContentList(keyword, contentResult);
#                         var educationResult = data.educationResults;
#                         self.changeEducationList(keyword, educationResult);
#                     }
#                 });
#                 this.showPopularKeyword = false;
#             },
#
#             /**
#              * 자동완성어에서 BOOK 부분에서 마우스를 올렸을 시에 발생하는 이벤트
#              * @param bookId
#              */
#             mouseOverBook: function mouseOverBook(bookId) {
#                 var currentBook = this.bookList.filter(function (book) {
#                     return book.id === bookId;
#                 });
#                 this.changeBookSummary(currentBook[0]);
#             },
#
#             /**
#              * 책 소개 변경
#              * @param book
#              */
#             changeBookSummary: function changeBookSummary(book) {
#                 if (book !== {}) {
#                     this.bookSummary.name = book.name;
#                     this.bookSummary.originName = book.originName;
#                     this.bookSummary.author = book.author;
#                     this.bookSummary.bookType = book.bookType;
#                     this.bookSummary.imgUrl = book.imgUrl;
#                     this.bookSummary.link = book.link;
#                     this.bookSummary.publishingCompany = book.publishingCompany;
#                     this.bookSummary.date = book.date;
#                     this.bookSummary.bookType = book.bookType;
#                 }
#             },
#
#             /**
#              * BOOK 리스트 변경
#              */
#             changeBookList: function changeBookList(keyword, bookResultList) {
#                 var self = this;
#                 self.bookList = [];
#                 var index = 0;
#
#                 if (bookResultList != null) {
#                     for (var _iterator2 = bookResultList, _isArray2 = Array.isArray(_iterator2), _i2 = 0, _iterator2 = _isArray2 ? _iterator2 : _iterator2[Symbol.iterator]();;) {
#                         var _ref2;
#
#                         if (_isArray2) {
#                             if (_i2 >= _iterator2.length) break;
#                             _ref2 = _iterator2[_i2++];
#                         } else {
#                             _i2 = _iterator2.next();
#                             if (_i2.done) break;
#                             _ref2 = _i2.value;
#                         }
#
#                         var result = _ref2;
#
#                         if (index < 10) {
#                             var book = {};
#                             book.id = result.code;
#                             book.originName = result.title;
#                             book.name = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             book.link = result.code;
#                             book.imgUrl = self.getBookImageURL(result.code);
#                             book.author = result.author;
#                             book.publishingCompany = result.brand;
#                             book.date = result.pubDate;
#                             book.bookType = result.bookType;
#                             self.bookList.push(book); //책 미리보기 변경
#
#                             self.changeBookSummary(self.bookList[0]);
#                         }
#                     }
#                 } else {
#                     self.initBookSummary();
#                 }
#             },
#
#             /**
#              * 책 이미지 주소 가져오기
#              */
#             getBookImageURL: function getBookImageURL(bookCode) {
#                 var imgURL;
#
#                 if (bookCode.substr(0, 1) === "E") {
#                     imgURL = '/data/ebook/' + bookCode + '_m.jpg';
#                 } else {
#                     imgURL = '/data/books/' + bookCode + "_m.jpg";
#                 }
#
#                 return imgURL;
#             },
#
#             /**
#              * 검색 결과가 없을 경우 책 미리보기 초기화
#              */
#             initBookSummary: function initBookSummary() {
#                 this.bookSummary = {
#                     'imgUrl': '',
#                     'link': '',
#                     'name': '',
#                     'author': '',
#                     'publishingCompany': '',
#                     'date': '',
#                     'bookType': ''
#                 };
#             },
#
#             /**
#              * education 리스트 변경
#              */
#             changeEducationList: function changeEducationList(keyword, educationResultList) {
#                 var self = this;
#                 self.educationList = [];
#                 var index = 0;
#
#                 if (educationResultList != null) {
#                     for (var _iterator3 = educationResultList, _isArray3 = Array.isArray(_iterator3), _i3 = 0, _iterator3 = _isArray3 ? _iterator3 : _iterator3[Symbol.iterator]();;) {
#                         var _ref3;
#
#                         if (_isArray3) {
#                             if (_i3 >= _iterator3.length) break;
#                             _ref3 = _iterator3[_i3++];
#                         } else {
#                             _i3 = _iterator3.next();
#                             if (_i3.done) break;
#                             _ref3 = _i3.value;
#                         }
#
#                         var result = _ref3;
#
#                         if (index < 3) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.educationList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * contents 리스트 변경
#              */
#             changeContentList: function changeContentList(keyword, contentResult) {
#                 var self = this;
#                 self.contentList = [];
#                 var index = 0;
#
#                 if (contentResult != null) {
#                     for (var _iterator4 = contentResult, _isArray4 = Array.isArray(_iterator4), _i4 = 0, _iterator4 = _isArray4 ? _iterator4 : _iterator4[Symbol.iterator]();;) {
#                         var _ref4;
#
#                         if (_isArray4) {
#                             if (_i4 >= _iterator4.length) break;
#                             _ref4 = _iterator4[_i4++];
#                         } else {
#                             _i4 = _iterator4.next();
#                             if (_i4.done) break;
#                             _ref4 = _i4.value;
#                         }
#
#                         var result = _ref4;
#
#                         if (index < 3) {
#                             var content = {};
#                             content.title = JSON.parse(JSON.stringify(self.replaceHighlightWord(result.title, keyword)));
#                             content.link = result.code;
#                             self.contentList.push(content);
#                             index = index + 1;
#                         }
#                     }
#                 }
#             },
#
#             /**
#              * 하이라이트 표시
#              */
#             replaceHighlightWord: function replaceHighlightWord(str, highlightKeyword) {
#                 var replaceHighlightKeyword = highlightKeyword.replace(/[^a-z0-9가-힣_ ]/gi, '');
#                 var regEx = new RegExp(replaceHighlightKeyword, "gi");
#                 str = str.replace(regEx, function (a) {
#                     return '<span class="keysel">' + a + '</span>';
#                 });
#                 return str;
#             },
#
#             /**
#              * 검색 버튼 클릭 시
#              * @param e
#              */
#             clickSearch: function clickSearch(e) {
#                 if (!this.keyword || this.keyword.length === 0) {
#                     alert("검색어를 입력하세요");
#                     $("#keyword_str").focus();
#                     e.preventDefault();
#                 } else {
#                     location.href = "/search/search_list.html?keyword=" + this.keyword;
#                 }
#             },
#
#             /**
#              * 인기 검색어 클릭시
#              * @param book
#              */
#             clickPopularKeyword: function clickPopularKeyword(book) {
#                 var searchKeyword = book.bookName;
#                 location.href = "/search/search_list.html?keyword=" + searchKeyword;
#             },
#
#             /**
#              * 책 검색어 클릭시 책 상세로 이동
#              * @param book
#              */
#             clickBookKeyword: function clickBookKeyword(book) {
#                 location.href = "/store/books/look.php?p_code=" + book.link;
#             },
#
#             /**
#              * 교육 클릭시 교육 상세로 이동
#              * @param education
#              */
#             clickEducationKeyword: function clickEducationKeyword(education) {
#                 location.href = "/store/education/edu_view.html?p_code=" + education.link;
#             },
#
#             /**
#              * 컨텐츠 클릭시 컨텐츠 상세로 이동
#              * @param contents
#              */
#             clickContentKeyword: function clickContentKeyword(content) {
#                 location.href = "/channel/category/category_view.html?cms_code=" + content.link;
#             }
#         }
#     });
# </script>
# <!-- //메인 검색 및 카테고리 영역 -->
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><script>alert('로그인이 필요한 서비스입니다.');location.href='/member/login.html';</script>

# %% [markdown]
# ### Selenium
#     -PhantomJS 또는 Chrome Driver
#     - pip install selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('C:\\chrome\\chromedriver')
driver.get('http://naver.com')

# %%
driver.save_screenshot("data/001.png")
# Out:
# True

# %%
url = "https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com"
driver = webdriver.Chrome('C:\\chrome\\chromedriver')
driver.get(url)

# %%
elem_login = driver.find_element_by_id('id')
elem_login.clear()
elem_login.send_keys('shdmf515')

elem_login = driver.find_element_by_id('pw')
elem_login.clear()
elem_login.send_keys('282shdmf++')

xpath = """//*[@id="log.login"]"""
driver.find_element_by_xpath(xpath).click()

# %% [markdown]
# ### 셀프 주유소 분석
#     http://www.opinet.co.kr

# %%
driver = webdriver.Chrome('C:\\chrome\\chromedriver')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
# 시 목록 가져오기
si_list_raw = driver.find_element_by_xpath("""//*[@id="SIDO_NM0"]""")
si_list = si_list_raw.find_elements_by_tag_name("option")
#si_list
si_names= [option.get_attribute("value") for option in si_list]
si_names.remove("")   # 맨 위 옵션에 시/도 값이 없음
si_names
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
# 시 선택하기
elem_id = driver.find_element_by_id("SIDO_NM0")
elem_id.send_keys(si_names)

# %%
# 구 목록 가져오기
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove("")
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
# 시 선택하기
gu_elem_id = driver.find_element_by_id("SIGUNGU_NM0")
gu_elem_id.send_keys(gu_names)

# %%
# 조회 버튼 누르기
xp="""//*[@id="searRgSelect"]/span"""
driver.find_element_by_xpath(xp).click()

# %%
# 엑셀 저장 버튼 누르기
xp = """//*[@id="glopopd_excel"]/span"""
driver.find_element_by_xpath(xp).click()

# %%
# 구별로 주유소 정보를 엑셀 파일로 저장
from tqdm import tqdm_notebook
import time

for gu in tqdm_notebook(gu_names):
    elem = driver.find_element_by_id("SIGUNGU_NM0")
    elem.send_keys(gu)
    
    time.sleep(2)
    
    xp = """//*[@id="searRgSelect"]/span"""
    driver.find_element_by_xpath(xp).click()
    
    time.sleep(1)
    
    xp = """//*[@id="glopopd_excel"]/span"""
    driver.find_element_by_xpath(xp).click()
    
    time.sleep(1)
    
driver.close()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=25.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-1336a8309941> in <module>
#       7     elem.send_keys(gu)
#       8
# ----> 9     time.sleep(2)
#      10
#      11     xp = """//*[@id="searRgSelect"]/span"""
#
# KeyboardInterrupt:

# %%
from glob import glob

station_files = glob("data/oil/지역*.xls")
station_files

tmp_raw = []
for filename in station_files:
    tmp = pd.read_excel(filename, header=2)
    tmp_raw.append(tmp)

# %%
len(tmp_raw)
# Out:
# 25

# %%
station_raw = pd.concat(tmp_raw)
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 0 to 40
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      499 non-null    object
#  1   상호      499 non-null    object
#  2   주소      499 non-null    object
#  3   상표      499 non-null    object
#  4   전화번호    499 non-null    object
#  5   셀프여부    499 non-null    object
#  6   고급휘발유   499 non-null    object
#  7   휘발유     499 non-null    object
#  8   경유      499 non-null    object
#  9   실내등유    499 non-null    object
# dtypes: object(10)
# memory usage: 42.9+ KB

# %%
station_raw.head()
# Out:
#       지역                 상호                        주소      상표          전화번호  \
# 0  서울특별시             구천면주유소     서울 강동구 구천면로 357 (암사동)  현대오일뱅크   02-441-0536
# 1  서울특별시  현대오일뱅크㈜직영 명일셀프주유소      서울 강동구 고덕로 168 (명일동)  현대오일뱅크  02-3428-1739
# 2  서울특별시      지에스칼텍스㈜ 신월주유소    서울 강동구 양재대로 1323 (성내동)   GS칼텍스   02-475-2600
# 3  서울특별시           sk해뜨는주유소  서울특별시 강동구  상일로 132 (강일동)   SK에너지   02-442-7801
# 4  서울특별시  현대오일뱅크㈜직영 암사셀프주유소     서울 강동구 올림픽로 749 (암사동)  현대오일뱅크  02-3427-2043
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    N     -  1344  1157     -
# 1    Y  1619  1345  1189     -
# 2    N  1555  1355  1169  1000
# 3    Y     -  1358  1218  1000
# 4    Y  1609  1359  1159     -

# %%
stations = pd.DataFrame({'Oil_store': station_raw['상호'],
                         '주소': station_raw['주소'],
                         '가격': station_raw['휘발유'],
                         '셀프': station_raw['셀프여부'],
                         '상표': station_raw['상표']
                        })
stations.head()
# Out:
#            Oil_store                        주소    가격 셀프      상표
# 0             구천면주유소     서울 강동구 구천면로 357 (암사동)  1344  N  현대오일뱅크
# 1  현대오일뱅크㈜직영 명일셀프주유소      서울 강동구 고덕로 168 (명일동)  1345  Y  현대오일뱅크
# 2      지에스칼텍스㈜ 신월주유소    서울 강동구 양재대로 1323 (성내동)  1355  N   GS칼텍스
# 3           sk해뜨는주유소  서울특별시 강동구  상일로 132 (강일동)  1358  Y   SK에너지
# 4  현대오일뱅크㈜직영 암사셀프주유소     서울 강동구 올림픽로 749 (암사동)  1359  Y  현대오일뱅크

# %%
stations['구'] = [addr.split()[1] for addr in stations['주소']]
stations.head()
# Out:
#            Oil_store                        주소    가격 셀프      상표    구
# 0             구천면주유소     서울 강동구 구천면로 357 (암사동)  1344  N  현대오일뱅크  강동구
# 1  현대오일뱅크㈜직영 명일셀프주유소      서울 강동구 고덕로 168 (명일동)  1345  Y  현대오일뱅크  강동구
# 2      지에스칼텍스㈜ 신월주유소    서울 강동구 양재대로 1323 (성내동)  1355  N   GS칼텍스  강동구
# 3           sk해뜨는주유소  서울특별시 강동구  상일로 132 (강일동)  1358  Y   SK에너지  강동구
# 4  현대오일뱅크㈜직영 암사셀프주유소     서울 강동구 올림픽로 749 (암사동)  1359  Y  현대오일뱅크  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations["가격"] =="-"]
stations = stations[stations['가격'] != '-']

# %%
stations['가격'] = [float(val) for val in stations['가격']]
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 38
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  492 non-null    object
#  1   주소         492 non-null    object
#  2   가격         492 non-null    float64
#  3   셀프         492 non-null    object
#  4   상표         492 non-null    object
#  5   구          492 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 26.9+ KB

# %%
stations.head(40)
stations.reset_index(inplace=True)

# %%
stations.head(40)
# Out:
#     index             Oil_store                          주소      가격 셀프  \
# 0       0                구천면주유소       서울 강동구 구천면로 357 (암사동)  1344.0  N
# 1       1     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168 (명일동)  1345.0  Y
# 2       2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323 (성내동)  1355.0  N
# 3       3              sk해뜨는주유소    서울특별시 강동구  상일로 132 (강일동)  1358.0  Y
# 4       4     현대오일뱅크㈜직영 암사셀프주유소       서울 강동구 올림픽로 749 (암사동)  1359.0  Y
# 5       5     현대오일뱅크㈜직영 고속셀프주유소            서울 강동구 천호대로 1246  1365.0  Y
# 6       6        지에스칼텍스㈜ 동서울주유소      서울 강동구 천호대로 1456 (상일동)  1375.0  Y
# 7       7               천호현대주유소         서울 강동구 천중로 67 (천호동)  1387.0  N
# 8       8      주)지유에너지직영 오렌지주유소        서울 강동구 성안로 102 (성내동)  1391.0  N
# 9       9               방아다리주유소        서울 강동구 동남로 811 (명일동)  1395.0  Y
# 10     10       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556 (성내동)  1398.0  Y
# 11     11        (주)삼표에너지 고덕주유소         서울 강동구 고덕로 39 (암사동)  1428.0  N
# 12     12       대성석유(주)직영 길동주유소            서울 강동구 천호대로 1168  1428.0  N
# 13     13                 광성주유소       서울 강동구 올림픽로 673 (천호동)  1448.0  N
# 14     14  (주)소모에너지엔테크놀러지 성내주유소       서울 강동구 올림픽로 578 (성내동)  1458.0  Y
# 15     15                 강동주유소       서울 강동구 양재대로 1509 (길동)  1798.0  N
# 16      0         재원에너지(주)용일주유소        서울 동대문구 안암로 54 (용두동)  1292.0  N
# 17      1                 풍한주유소             서울 동대문구 안암로 168  1295.0  N
# 18      2               재정제2주유소       서울 동대문구 사가정로 90 (전농동)  1297.0  Y
# 19      3                 재정주유소       서울 동대문구 전농로 121 (전농동)  1297.0  N
# 20      4              (주)경동주유소       서울 동대문구 이문로 191 (이문동)  1299.0  Y
# 21      5          동일석유(주)강남주유소  서울특별시 동대문구  사가정로 103 (전농동)  1319.0  N
# 22      6                 웰컴주유소       서울 동대문구 한천로 414 (이문동)  1325.0  N
# 23      7                배봉로주유소          서울 동대문구 서울시립대로 108  1325.0  Y
# 24      8      현대오일뱅크㈜직영 스피드주유소      서울 동대문구 천호대로 453 (장안동)  1329.0  N
# 25      9                 홍능주유소       서울 동대문구 홍릉로 87 (청량리동)  1347.0  N
# 26     10              (주)열린주유소       서울 동대문구 한천로 263 (휘경동)  1349.0  N
# 27     11                답십리주유소     서울 동대문구 답십리로 223 (답십리동)  1349.0  N
# 28     12                 삼영주유소      서울 동대문구 답십리로 258 (장안동)  1349.0  N
# 29     13              (주)파랑에너지               서울 동대문구 망우로 1  1355.0  Y
# 30     14               삼원셀프주유소        서울 동대문구 망우로 90 (휘경동)  1358.0  Y
# 31     15         대성산업(주)동마장주유소      서울 동대문구 고산자로 405 (용두동)  1388.0  N
# 32     16       삼미상사(주)장안킹셀프주유소      서울 동대문구  한천로 100 (장안동)  1389.0  Y
# 33     17                 신성주유소        서울 동대문구 장한로 29 (장안동)  1397.0  N
# 34     18               오동나무주유소      서울 동대문구  한천로 81 (답십리동)  1398.0  N
# 35     19           대성산업㈜청량리주유소      서울 동대문구 왕산로 289 (청량리동)  1399.0  N
# 36     20            한영주유소 (한화)        서울 동대문구 망우로 38 (휘경동)  1455.0  N
# 37     21                 능주주유소      서울 동대문구 청계천로 431 (신설동)  1505.0  N
# 38      0                 창원ENG         서울 동작구 사당로 59 (상도동)  1319.0  N
# 39      1    현대오일뱅크㈜직영 흑석동셀프주유소        서울 동작구 현충로 101 (흑석동)  1320.0  Y
#
#         상표     구
# 0   현대오일뱅크   강동구
# 1   현대오일뱅크   강동구
# 2    GS칼텍스   강동구
# 3    SK에너지   강동구
# 4   현대오일뱅크   강동구
# 5   현대오일뱅크   강동구
# 6    GS칼텍스   강동구
# 7   현대오일뱅크   강동구
# 8    SK에너지   강동구
# 9    SK에너지   강동구
# 10   S-OIL   강동구
# 11   GS칼텍스   강동구
# 12   GS칼텍스   강동구
# 13   S-OIL   강동구
# 14   GS칼텍스   강동구
# 15   SK에너지   강동구
# 16   GS칼텍스  동대문구
# 17   SK에너지  동대문구
# 18  현대오일뱅크  동대문구
# 19  현대오일뱅크  동대문구
# 20   S-OIL  동대문구
# 21   SK에너지  동대문구
# 22  현대오일뱅크  동대문구
# 23  현대오일뱅크  동대문구
# 24  현대오일뱅크  동대문구
# 25   S-OIL  동대문구
# 26   GS칼텍스  동대문구
# 27   GS칼텍스  동대문구
# 28   SK에너지  동대문구
# 29   GS칼텍스  동대문구
# 30   SK에너지  동대문구
# 31   GS칼텍스  동대문구
# 32   SK에너지  동대문구
# 33  현대오일뱅크  동대문구
# 34   S-OIL  동대문구
# 35   GS칼텍스  동대문구
# 36  현대오일뱅크  동대문구
# 37   SK에너지  동대문구
# 38  현대오일뱅크   동작구
# 39  현대오일뱅크   동작구

# %%
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  492 non-null    object
#  1   주소         492 non-null    object
#  2   가격         492 non-null    float64
#  3   셀프         492 non-null    object
#  4   상표         492 non-null    object
#  5   구          492 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 23.2+ KB

# %%
stations.boxplot(column="가격", by="셀프", figsize=(12,8))

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations)

# %%
import json
import folium
import googlemaps

# %%
# 서울시에서 가장 주유 가격이 비싼곳이 어디인가?
stations.sort_values(by="가격",ascending=False).head(10)
# Out:
#             Oil_store                       주소      가격 셀프      상표    구
# 301             서남주유소             서울 중구 통일로 30  2143.0  N   SK에너지   중구
# 300      에스씨(주) 역전주유소             서울 중구 퇴계로 15  2119.0  N   GS칼텍스   중구
# 264             서계주유소     서울 용산구 청파로 367 (서계동)  2059.0  N   GS칼텍스  용산구
# 299             필동주유소    서울 중구  퇴계로 196 (필동2가)  2059.0  N   GS칼텍스   중구
# 491           뉴서울(강남)     서울 강남구 언주로 716 (논현동)  2025.0  N   SK에너지  강남구
# 298   SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2019.0  N   SK에너지   중구
# 263  현대오일뱅크㈜직영 갈월동주유소    서울 용산구 한강대로 322 (갈월동)  2009.0  N  현대오일뱅크  용산구
# 262            동자동주유소  서울 용산구 한강대로104길 6 (동자동)  1990.0  N   SK에너지  용산구
# 260              에너비스     서울 용산구 한남대로 82 (한남동)  1978.0  N   SK에너지  용산구
# 261              한남지점   서울 용산구 한남대로21길 4 (한남동)  1978.0  N   SK에너지  용산구

# %%
# 서울시에서 가장 주유 가격이 싼곳이 어디인가?
stations.sort_values(by="가격",ascending=True).head(10)
# Out:
#           Oil_store                        주소      가격 셀프      상표    구
# 75         만남의광장주유소      서울 서초구 양재대로12길 73-71  1259.0  Y  알뜰(ex)  서초구
# 127  (주)삼표에너지 정릉주유소      서울 성북구 보국문로 35 (정릉동)  1267.0  Y   GS칼텍스  성북구
# 126         강산제2주유소            서울 성북구 보국문로 52  1267.0  Y  현대오일뱅크  성북구
# 128           원천주유소     서울 성북구 돌곶이로 142 (장위동)  1275.0  N   알뜰주유소  성북구
# 129   이케이에너지㈜ 강산주유소     서울 성북구 보문로 27 (보문동7가)  1277.0  Y   GS칼텍스  성북구
# 130           신방주유소    서울 성북구 안암로 111 (안암동5가)  1282.0  N   S-OIL  성북구
# 319          화곡역주유소  서울특별시 강서구  강서로 154 (화곡동)  1284.0  Y   알뜰주유소  강서구
# 318          뉴신정주유소      서울 강서구 곰달래로 207(화곡동)  1284.0  N   알뜰주유소  강서구
# 182           현대주유소    서울 양천구 남부순환로 372 (신월동)  1285.0  Y   S-OIL  양천구
# 131           장위주유소     서울 성북구 화랑로 110 (하월곡동)  1285.0  Y   S-OIL  성북구

# %%
gu_data = pd.pivot_table(stations, index=["구"], values=["가격"])
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1539.128205
# 강동구  1414.500000
# 강북구  1306.833333
# 강서구  1360.676471
# 관악구  1368.687500

# %%
geo_path = "data/seoul/skorea_municipalities_geo_simple_seoul.json"

geo_str = json.load(open(geo_path, encoding="utf-8"))
geo_str

map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map.choropleth(geo_data=geo_str, data=gu_data,
              columns=[gu_data.index, "가격"],
              key_on="feature.id", fill_color="YlGn")
map
# Out:
# C:\Users\user\anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)

# %%
oil_price_top10 
#oil_price_bottom10
# Out:
#             Oil_store                       주소      가격 셀프      상표    구
# 301             서남주유소             서울 중구 통일로 30  2143.0  N   SK에너지   중구
# 300      에스씨(주) 역전주유소             서울 중구 퇴계로 15  2119.0  N   GS칼텍스   중구
# 264             서계주유소     서울 용산구 청파로 367 (서계동)  2059.0  N   GS칼텍스  용산구
# 299             필동주유소    서울 중구  퇴계로 196 (필동2가)  2059.0  N   GS칼텍스   중구
# 491           뉴서울(강남)     서울 강남구 언주로 716 (논현동)  2025.0  N   SK에너지  강남구
# 298   SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2019.0  N   SK에너지   중구
# 263  현대오일뱅크㈜직영 갈월동주유소    서울 용산구 한강대로 322 (갈월동)  2009.0  N  현대오일뱅크  용산구
# 262            동자동주유소  서울 용산구 한강대로104길 6 (동자동)  1990.0  N   SK에너지  용산구
# 260              에너비스     서울 용산구 한남대로 82 (한남동)  1978.0  N   SK에너지  용산구
# 261              한남지점   서울 용산구 한남대로21길 4 (한남동)  1978.0  N   SK에너지  용산구

# %%
oil_price_top10.index
# Out:
# Int64Index([301, 300, 264, 299, 491, 298, 263, 262, 260, 261], dtype='int64')

# %%
g_map=googlemaps.Client(key="AIzaSyDskZhiN7vXmbmvqfe9yRMJP1r8wfj7Jvw")

lat = []
lng = []


for n in oil_price_top10.index:
    tmp_add = oil_price_top10['주소'][n].split('(')[0]   #()인식못한다
    tmp_map = g_map.geocode(tmp_add)
    
    tmp_loc = tmp_map[0].get('geometry')
    lat.append(tmp_loc['location']['lat'])
    lng.append(tmp_loc['location']['lng'])

# %%
oil_price_top10["lat"] = lat
oil_price_top10['lng'] = lng

# %%
g_map = googlemaps.Client(key="AIzaSyCBC7RyE_1ayBhjoUuVOF3EDSvvzEej2kY")

lat1 = []
lng1 = []

for n in oil_price_bottom10.index:
    tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
    tmp_map = g_map.geocode(tmp_add)
    
    tmp_loc = tmp_map[0].get('geometry')
    lat1.append(tmp_loc['location']['lat'])
    lng1.append(tmp_loc['location']['lng'])

# %%
oil_price_bottom10["lat1"] = lat
oil_price_bottom10["lng1"] = lng
oil_price_bottom10
# Out:
#           Oil_store                        주소      가격 셀프      상표    구  \
# 75         만남의광장주유소      서울 서초구 양재대로12길 73-71  1259.0  Y  알뜰(ex)  서초구
# 127  (주)삼표에너지 정릉주유소      서울 성북구 보국문로 35 (정릉동)  1267.0  Y   GS칼텍스  성북구
# 126         강산제2주유소            서울 성북구 보국문로 52  1267.0  Y  현대오일뱅크  성북구
# 128           원천주유소     서울 성북구 돌곶이로 142 (장위동)  1275.0  N   알뜰주유소  성북구
# 129   이케이에너지㈜ 강산주유소     서울 성북구 보문로 27 (보문동7가)  1277.0  Y   GS칼텍스  성북구
# 130           신방주유소    서울 성북구 안암로 111 (안암동5가)  1282.0  N   S-OIL  성북구
# 319          화곡역주유소  서울특별시 강서구  강서로 154 (화곡동)  1284.0  Y   알뜰주유소  강서구
# 318          뉴신정주유소      서울 강서구 곰달래로 207(화곡동)  1284.0  N   알뜰주유소  강서구
# 182           현대주유소    서울 양천구 남부순환로 372 (신월동)  1285.0  Y   S-OIL  양천구
# 131           장위주유소     서울 성북구 화랑로 110 (하월곡동)  1285.0  Y   S-OIL  성북구
#
#           lat1        lng1
# 75   37.558348  126.972090
# 127  37.557001  126.974495
# 126  37.552290  126.968935
# 128  37.560850  126.993653
# 129  37.517636  127.035756
# 130  37.561648  126.997142
# 319  37.546955  126.972218
# 318  37.550179  126.972463
# 182  37.535952  127.006130
# 131  37.534657  127.006063

# %%
lat1 = []
lng1 = []

for n in oil_price_top10.index:
    tmp_add = oil_price_top10['주소'][n].split('(')[0]
    tmp_map = g_map.geocode(tmp_add)
    
    tmp_loc = tmp_map[0].get('geometry')
    lat1.append(tmp_loc['location']['lat'])
    lng1.append(tmp_loc['location']['lng'])
    
oil_price_top10['lat'] = lat1
oil_price_top10['lng'] = lng1

lat2 = []
lng2 = []

for n in oil_price_bottom10.index:
    tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
    tmp_map = g_map.geocode(tmp_add)
    
    tmp_loc = tmp_map[0].get('geometry')
    lat2.append(tmp_loc['location']['lat'])
    lng2.append(tmp_loc['location']['lng'])

oil_price_bottom10['lat'] = lat2
oil_price_bottom10['lng'] = lng2
oil_price_bottom10

map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in oil_price_top10.index:
    folium.CircleMarker(
            location=[oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
            radius=15, 
            color="#CD3181", 
            fill_color="#CD3181",
            fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    folium.CircleMarker(
            location=[oil_price_bottom10["lat"][n], oil_price_bottom10["lng"][n]], 
            radius=15, 
            color="#3186CC", 
            fill_color="#3186CC",
            fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
